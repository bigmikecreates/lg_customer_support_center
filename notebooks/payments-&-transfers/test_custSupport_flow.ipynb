# %% [markdown]
# <div align='center'>
#
# # OVERVIEW
#
# Customer **Support** Demos.
# </div>

# %% [markdown]
# In-line with the defined persona document ([click to open 'customer_support_rep_persona' document](customer_rep_persona_store\customer_support_rep_persona.md)), this notebook defines common KYC operations to be applied by a customer support representative.

# %% [markdown]
# # Required Modules

# %%
import os
import requests_oauthlib
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Setup
